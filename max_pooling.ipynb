# %%
from model import layers, activations, networks, preprocessing, optimizers, losses
import numpy as np
import matplotlib.pyplot as plt

# %%
conv_output = np.random.randint(0, 255, (16, 16, 3))
conv_output
# Out:
# array([[[162,  52,  90],
#         [182, 104, 243],
#         [201,  97,  55],
#         [238, 138,  70],
#         [174, 132, 167],
#         [145, 127, 135],
#         [ 79, 254, 135],
#         [197, 107, 128],
#         [112,  48, 214],
#         [160, 246,  38],
#         [147,  14,   5],
#         [ 22, 186,  51],
#         [ 24, 227, 246],
#         [196, 115, 203],
#         [224,  34, 173],
#         [161, 106, 182]],
#
#        [[ 59, 222,  43],
#         [ 69, 252,  57],
#         [142, 109,  34],
#         [172,  50, 243],
#         [207,  21, 112],
#         [221,  76, 101],
#         [236, 218, 154],
#         [124, 239, 170],
#         [ 34, 106, 162],
#         [ 41,  71,  43],
#         [ 43, 129, 149],
#         [ 79, 147, 144],
#         [153, 197,  70],
#         [ 43, 173, 162],
#         [175, 201, 111],
#         [152, 155,  18]],
#
#        [[107, 211,  95],
#         [ 97, 189, 197],
#         [184, 179,  21],
#         [ 38,  74, 216],
#         [ 82, 162,  90],
#         [238, 195,  90],
#         [143, 212,  16],
#         [168, 167,  77],
#         [225, 119, 147],
#         [239, 159, 114],
#         [254, 252, 237],
#         [117, 149,  49],
#         [219,  33,  50],
#         [ 76, 208, 244],
#         [ 83, 194, 243],
#         [ 17, 229, 208]],
#
#        [[ 37,  53, 186],
#         [189,  44,  49],
#         [ 11,  27, 243],
#         [202, 152, 226],
#         [249,  44, 204],
#         [ 40,  65,  51],
#         [ 43, 187, 108],
#         [243,  39, 146],
#         [ 72, 203,  82],
#         [ 20, 234, 145],
#         [  3, 226,  57],
#         [119, 174,  46],
#         [ 78,  57, 127],
#         [116,  26, 184],
#         [ 33,  73, 134],
#         [ 63,  12, 204]],
#
#        [[151, 150, 202],
#         [ 23,  26, 177],
#         [ 26, 243, 201],
#         [184, 135, 115],
#         [135, 238, 177],
#         [ 80,  32,  18],
#         [160, 168, 240],
#         [192, 137, 241],
#         [182, 225,   7],
#         [112, 215, 219],
#         [203,  42,   8],
#         [193, 110, 204],
#         [183, 243,  42],
#         [ 72, 220, 186],
#         [192, 203, 204],
#         [ 12,  74, 108]],
#
#        [[159, 220,  39],
#         [225, 106, 214],
#         [250,  19,  48],
#         [ 31, 115, 182],
#         [129, 251, 192],
#         [212, 102, 226],
#         [ 77,  36, 120],
#         [220, 254, 105],
#         [ 71,  99, 201],
#         [169,  60, 160],
#         [ 19,  70, 228],
#         [ 52,   5,  85],
#         [100, 226,  57],
#         [131,   2, 214],
#         [224, 122,  81],
#         [ 82, 120, 130]],
#
#        [[ 62, 232,  91],
#         [  9,   7,  84],
#         [ 15, 147, 220],
#         [232, 235,  33],
#         [144,  45, 111],
#         [123,  75,  74],
#         [ 23,  91, 181],
#         [ 34, 242, 127],
#         [ 44, 177,  44],
#         [193, 101,  76],
#         [109, 215, 214],
#         [148,  43, 164],
#         [ 40, 253, 195],
#         [208, 100, 174],
#         [115, 197,  11],
#         [ 20,  39, 112]],
#
#        [[ 98, 137, 175],
#         [228,  40,  38],
#         [ 77,   5,  83],
#         [147,  42, 170],
#         [232,  23, 169],
#         [117, 157,  78],
#         [244, 136,  29],
#         [ 20,  92, 115],
#         [107, 198,  18],
#         [160,  59, 147],
#         [112, 140, 124],
#         [180, 119,   8],
#         [146, 120,  45],
#         [122, 220,  89],
#         [ 87, 182, 101],
#         [104,  20, 240]],
#
#        [[ 40, 143, 149],
#         [194, 250, 235],
#         [139, 154,  42],
#         [  7, 213,  85],
#         [171, 140, 168],
#         [225,  18,  33],
#         [  4,  22,  51],
#         [147, 220,  44],
#         [227, 249, 117],
#         [160, 234,  83],
#         [111,  83,  43],
#         [129, 162,  19],
#         [ 95,  66, 245],
#         [253, 126, 167],
#         [139,  30,  98],
#         [  8, 153,   1]],
#
#        [[ 39, 177, 123],
#         [ 67,  57,  91],
#         [224, 250, 227],
#         [ 97, 125, 144],
#         [177,  98, 213],
#         [143, 162, 156],
#         [ 82,  78,  45],
#         [149,  11, 214],
#         [218, 134,  83],
#         [253,  63,  12],
#         [132, 161, 241],
#         [253,  82, 239],
#         [ 95, 247, 152],
#         [203,  44,  82],
#         [194,  50, 148],
#         [192,  58, 213]],
#
#        [[180, 116,  13],
#         [ 28, 229, 178],
#         [136, 218, 105],
#         [ 91, 126, 165],
#         [ 70, 144, 195],
#         [ 78,  87, 163],
#         [ 60, 248,  45],
#         [ 31, 245,  61],
#         [155, 248,  14],
#         [245, 158, 111],
#         [ 64, 138, 204],
#         [146, 229,   6],
#         [ 47, 104, 187],
#         [211,  69,  84],
#         [103, 138, 249],
#         [ 56, 180, 212]],
#
#        [[ 58,  49,  69],
#         [119,  58,  37],
#         [152, 160,   7],
#         [159,  81, 177],
#         [ 89, 108, 235],
#         [ 50,  47,  52],
#         [ 76,  83, 206],
#         [  6,  88, 216],
#         [100, 138, 223],
#         [ 18, 227, 217],
#         [128, 178, 191],
#         [216, 117,  77],
#         [194, 254, 121],
#         [156, 205, 233],
#         [  6,  30, 137],
#         [ 84, 145,  23]],
#
#        [[155,  43, 162],
#         [243,   4,  74],
#         [197, 107,  60],
#         [197,  62, 123],
#         [ 75, 118, 102],
#         [ 29,  74,  14],
#         [146, 132, 187],
#         [253, 250,  50],
#         [250,  24,  27],
#         [194, 198,  70],
#         [  9,  62, 104],
#         [241, 200,   6],
#         [195, 127,  62],
#         [234, 199,  32],
#         [ 62, 179, 108],
#         [231,  81, 232]],
#
#        [[232,  58, 141],
#         [ 22, 104, 147],
#         [ 16,  89,   5],
#         [131, 174,  12],
#         [237,  98, 249],
#         [ 49, 125, 182],
#         [ 70,  21,  38],
#         [ 86,  47, 218],
#         [ 99, 109, 233],
#         [ 70,  71, 192],
#         [ 64, 248, 184],
#         [202,  53, 223],
#         [118, 212, 138],
#         [ 23,  77, 192],
#         [ 38,   4,   9],
#         [136,  56, 108]],
#
#        [[196,  38, 242],
#         [211,   4, 179],
#         [126, 118,  13],
#         [ 79, 144,  58],
#         [ 58,   7, 123],
#         [205,  14,  85],
#         [130, 152, 203],
#         [ 84, 194,  82],
#         [135, 249,  99],
#         [157, 186,   1],
#         [ 15, 207,  23],
#         [ 24,   0, 213],
#         [186,  95,  88],
#         [227,   4,  29],
#         [ 68, 116,  99],
#         [ 69,  30,  95]],
#
#        [[ 39,  23, 110],
#         [203, 217, 248],
#         [ 58, 122, 113],
#         [ 70,  92,   8],
#         [ 43, 183, 150],
#         [ 31, 178,  70],
#         [115, 223, 112],
#         [110, 141,  48],
#         [210, 254, 224],
#         [ 25, 157, 248],
#         [252, 115, 244],
#         [121,  38, 129],
#         [220,  14,  33],
#         [ 74,  34,  74],
#         [ 72, 189, 146],
#         [130,  92, 150]]])

# %%
window = (2, 2)

# %%
for channel in range(conv_output.shape[2]):
    image = conv_output[:, :, channel]
    width = image.shape[1]
    height = image.shape [0]
    step = window[0]

    output = np.zeros((int(height / step), int(width / step)))

    for y in range(int(height / step)):
        for x in range(int(width / step)):
            arr = image[y * step : y * step + step, x * step : x * step + step]
            output[y, x] = np.max(arr)

    print(output)
# Out:
# [[182. 238. 221. 236. 160. 147. 196. 224.]
#  [189. 202. 249. 243. 239. 254. 219.  83.]
#  [225. 250. 212. 220. 182. 203. 183. 224.]
#  [228. 232. 232. 244. 193. 180. 208. 115.]
#  [194. 224. 225. 149. 253. 253. 253. 194.]
#  [180. 159.  89.  76. 245. 216. 211. 103.]
#  [243. 197. 237. 253. 250. 241. 234. 231.]
#  [211. 126. 205. 130. 210. 252. 227. 130.]]
# [[252. 138. 132. 254. 246. 186. 227. 201.]
#  [211. 179. 195. 212. 234. 252. 208. 229.]
#  [220. 243. 251. 254. 225. 110. 243. 203.]
#  [232. 235. 157. 242. 198. 215. 253. 197.]
#  [250. 250. 162. 220. 249. 162. 247. 153.]
#  [229. 218. 144. 248. 248. 229. 254. 180.]
#  [104. 174. 125. 250. 198. 248. 212. 179.]
#  [217. 144. 183. 223. 254. 207.  95. 189.]]
# [[243. 243. 167. 170. 214. 149. 246. 182.]
#  [197. 243. 204. 146. 147. 237. 244. 243.]
#  [214. 201. 226. 241. 219. 228. 214. 204.]
#  [175. 220. 169. 181. 147. 214. 195. 240.]
#  [235. 227. 213. 214. 117. 241. 245. 213.]
#  [178. 177. 235. 216. 223. 204. 233. 249.]
#  [162. 123. 249. 218. 233. 223. 192. 232.]
#  [248. 113. 150. 203. 248. 244.  88. 150.]]
